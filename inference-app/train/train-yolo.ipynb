# %%
# !nvidia-smi
# Out:
# Sun Mar 23 21:08:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   42C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working/datasets

# %%
# %pip install "ultralytics" supervision roboflow

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6170.1/8062.4 GB disk)

# %%
# %pip install "ray[tune]"
# Out:
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.10/dist-packages (2.42.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (3.17.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.2.3)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (19.0.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2024.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX>=1.9->ray[tune]) (1.26.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (2025.1.31)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->tensorboardX>=1.9->ray[tune]) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->tensorboardX>=1.9->ray[tune]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->tensorboardX>=1.9->ray[tune]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->tensorboardX>=1.9->ray[tune]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->tensorboardX>=1.9->ray[tune]) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->tensorboardX>=1.9->ray[tune]) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /kaggle/working/datasets/datasets

# %%
import os

dataset = "/kaggle/input/fruitsandvegetablesroi/"

print("Fișiere disponibile:", os.listdir(dataset))
# Out:
# Fișiere disponibile: ['README.roboflow.txt', 'data.yaml', 'valid', 'test', 'train']

# %%
# %cd {HOME}
# Out:
# /kaggle/working/datasets

# %%
pip install ray==2.7.1
# Out:
# Collecting ray==2.7.1
#   Downloading ray-2.7.1-cp310-cp310-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (3.17.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (2.32.3)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->ray==2.7.1) (2.4.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (2025.1.31)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->ray==2.7.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->ray==2.7.1) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->ray==2.7.1) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.3->ray==2.7.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.3->ray==2.7.1) (2024.2.0)
# Downloading ray-2.7.1-cp310-cp310-manylinux2014_x86_64.whl (62.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 MB 27.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.42.1
#     Uninstalling ray-2.42.1:
#       Successfully uninstalled ray-2.42.1
# Successfully installed ray-2.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !yolo task=detect mode=train model=/kaggle/input/run_roi_2/pytorch/default/1/last.pt \
    data=/kaggle/input/fruitsandvegetablesroi/data.yaml epochs=35 \
    imgsz=640 batch=22 workers=8 device=0,1 optimizer=AdamW \
    lr0=0.002 lrf=0.01 momentum=0.937 weight_decay=0.0004 \
    warmup_epochs=3 warmup_momentum=0.8 warmup_bias_lr=0.1 \
    cache=False dropout=0.05 \
    hsv_h=0.015 hsv_s=0.4 hsv_v=0.3 \
    degrees=2 translate=0.05 scale=0.2 shear=1.0 \
    flipud=0.05 fliplr=0.2 mosaic=0.3 mixup=0.05 copy_paste=0.05 \
    close_mosaic=2 overlap_mask=True mask_ratio=4 \
    patience=10 save=True plots=True val=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.95 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=/kaggle/input/run_roi_2/pytorch/default/1/last.pt, data=/kaggle/input/fruitsandvegetablesroi/data.yaml, epochs=35, time=None, patience=10, batch=22, imgsz=640, save=True, save_period=-1, cache=False, device=(0, 1), workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=2, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.05, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.002, lrf=0.01, momentum=0.937, weight_decay=0.0004, warmup_epochs=3, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.4, hsv_v=0.3, degrees=2, translate=0.05, scale=0.2, shear=1.0, perspective=0.0, flipud=0.05, fliplr=0.2, bgr=0.0, mosaic=0.3, mixup=0.05, copy_paste=0.05, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3146707  ultralytics.nn.modules.head.Detect           [1, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,874,931 parameters, 56,874,915 gradients, 195.4 GFLOPs
#
# Transferred 1015/1015 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 41285 /root/.config/Ultralytics/DDP/_temp_hffeemfw137754562823168.py
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Transferred 1015/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 21491 image
# train: WARNING ⚠️ Cache directory /kaggle/input/fruitsandvegetablesroi/train is not writeable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1106, len(boxes) = 52630. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/input/fruitsandvegetablesroi/valid/labels... 4248 images,
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 9098 imagesval: WARNING ⚠️ Cache directory /kaggle/input/fruitsandvegetablesroi/valid is not writeable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 91, len(boxes) = 10293. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 10212 imagePlotting labels to runs/detect/train2/labels.jpg...
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 14089 imageoptimizer: AdamW(lr=0.002, momentum=0.937) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0004125), 173 bias(decay=0.0)
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 21491 image
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 35 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/35      11.3G     0.7877     0.6065      1.253         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4248      10293      0.868      0.816      0.889      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/35      11.3G     0.7735     0.5841      1.239         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4248      10293     0.0526      0.372     0.0453     0.0317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/35      11.1G     0.7748     0.5914      1.242         36        640:

# %%
# !zip -r /kaggle/working/runs.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/train_batch2.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train/results.csv (deflated 59%)
#   adding: kaggle/working/runs/detect/train/val_batch2_pred.jpg (deflated 22%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 39%)
#   adding: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 14%)
#   adding: kaggle/working/runs/detect/train/labels_correlogram.jpg (deflated 29%)
#   adding: kaggle/working/runs/detect/train/PR_curve.png (deflated 21%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 24%)
#   adding: kaggle/working/runs/detect/train/train_batch0.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train/val_batch0_labels.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/val_batch0_pred.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train/results.png (deflated 7%)
#   adding: kaggle/working/runs/detect/train/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/detect/train/train_batch17586.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 7%)
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 7%)
#   adding: kaggle/working/runs/detect/train/train_batch17588.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 39%)
#   adding: kaggle/working/runs/detect/train/val_batch1_pred.jpg (deflated 14%)
#   adding: kaggle/working/runs/detect/train/F1_curve.png (deflated 17%)
#   adding: kaggle/working/runs/detect/train/train_batch17587.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/R_curve.png (deflated 17%)
#   adding: kaggle/working/runs/detect/train/labels.jpg (deflated 34%)
#   adding: kaggle/working/runs/detect/train/P_curve.png (deflated 20%)
#   adding: kaggle/working/runs/detect/train/events.out.tfevents.1742724855.d55a64bb7126.103.0 (deflated 94%)

# %%
# !yolo task=detect mode=train model=/kaggle/input/runs_roi_3_last/pytorch/default/1/last.pt \
    data=/kaggle/input/fruitsandvegetablesroi/data.yaml epochs=20 \
    imgsz=640 batch=22 workers=8 device=0,1 optimizer=AdamW \
    lr0=0.0035 lrf=0.015 momentum=0.94 weight_decay=0.0004 \
    warmup_epochs=3 warmup_momentum=0.85 warmup_bias_lr=0.1 \
    cache=True dropout=0.05 \
    hsv_h=0.015 hsv_s=0.5 hsv_v=0.3 \
    degrees=5 translate=0.1 scale=0.3 shear=2.0 \
    flipud=0.1 fliplr=0.4 mosaic=0.8 mixup=0.1 copy_paste=0.1 \
    close_mosaic=2 overlap_mask=True mask_ratio=4 \
    save=True plots=True val=True
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=/kaggle/input/runs_roi_3_last/pytorch/default/1/last.pt, data=/kaggle/input/fruitsandvegetablesroi/data.yaml, epochs=20, time=None, patience=100, batch=22, imgsz=640, save=True, save_period=-1, cache=True, device=(0, 1), workers=8, project=None, name=train8, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=2, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.05, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.0035, lrf=0.015, momentum=0.94, weight_decay=0.0004, warmup_epochs=3, warmup_momentum=0.85, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.5, hsv_v=0.3, degrees=5, translate=0.1, scale=0.3, shear=2.0, perspective=0.0, flipud=0.1, fliplr=0.4, bgr=0.0, mosaic=0.8, mixup=0.1, copy_paste=0.1, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3146707  ultralytics.nn.modules.head.Detect           [1, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,874,931 parameters, 56,874,915 gradients, 195.4 GFLOPs
#
# Transferred 1015/1015 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 44225 /root/.config/Ultralytics/DDP/_temp_79dk4er3135627124818992.py
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train8', view at http://localhost:6006/
# Transferred 1015/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 21491 image
# train: WARNING ⚠️ Cache directory /kaggle/input/fruitsandvegetablesroi/train is not writeable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1106, len(boxes) = 52630. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# train: 36.9GB RAM required to cache images with 50% safety margin but only 25.3/31.4GB available, not caching images ⚠️
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/input/fruitsandvegetablesroi/valid/labels... 4248 images,
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 10430 imageval: WARNING ⚠️ Cache directory /kaggle/input/fruitsandvegetablesroi/valid is not writeable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 91, len(boxes) = 10293. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 10560 imageWARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (4.9GB RAM): 100%|██████████| 4248/4248 [00:08<00:00, 505.14
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 16451 imagePlotting labels to runs/detect/train8/labels.jpg...
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 19433 imageoptimizer: AdamW(lr=0.0035, momentum=0.94) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0004125), 173 bias(decay=0.0)
# train: Scanning /kaggle/input/fruitsandvegetablesroi/train/labels... 21491 image
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train8
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      11.3G     0.8513      0.659      1.297         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4248      10293      0.708      0.658      0.656      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      11.3G     0.8389     0.6425      1.282         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4248      10293   0.000365     0.0452   0.000199   8.53e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      11.1G     0.8448     0.6454      1.291         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4248      10293    0.00771    0.00573   0.000998   0.000425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      11.2G     0.8819     0.6231      1.295         46        640:  ^C
# W0323 21:07:31.118000 664 torch/distributed/elastic/agent/server/api.py:704] Received Signals.SIGINT death signal, shutting down workers
# W0323 21:07:31.119000 664 torch/distributed/elastic/multiprocessing/api.py:897] Sending process 666 closing signal SIGINT
# W0323 21:07:31.119000 664 torch/distributed/elastic/multiprocessing/api.py:897] Sending process 667 closing signal SIGINT
#        4/20      11.2G     0.8819     0.6231      1.295         46        640:
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/root/.config/Ultralytics/DDP/_temp_79dk4er3135627124818992.py", line 13, in <module>
# [rank0]:     results = trainer.train()
# [rank0]:   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py", line 211, in train
# [rank0]:     self._do_train(world_size)
# [rank0]:   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py", line 396, in _do_train
# [rank0]:     self.optimizer_step()
# [rank0]:   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py", line 614, in optimizer_step
# [rank0]:     self.ema.update(self.model)
# [rank0]:   File "/usr/local/lib/python3.10/dist-packages/ultralytics/utils/torch_utils.py", line -1, in update
# [rank0]: KeyboardInterrupt

# %%
# !zip -r /kaggle/working/runs.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/results.csv (deflated 50%)
#   adding: kaggle/working/runs/detect/train/labels_correlogram.jpg (deflated 29%)
#   adding: kaggle/working/runs/detect/train/events.out.tfevents.1742647912.29dbe97fb40b.94.0 (deflated 94%)
#   adding: kaggle/working/runs/detect/train/labels.jpg (deflated 34%)
#   adding: kaggle/working/runs/detect/train/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 44%)
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 44%)
#   adding: kaggle/working/runs/detect/train/train_batch0.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/train_batch2.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train2/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/val_batch0_pred.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/results.csv (deflated 56%)
#   adding: kaggle/working/runs/detect/train2/train_batch7816.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train2/results.png (deflated 7%)
#   adding: kaggle/working/runs/detect/train2/val_batch2_labels.jpg (deflated 24%)
#   adding: kaggle/working/runs/detect/train2/labels_correlogram.jpg (deflated 29%)
#   adding: kaggle/working/runs/detect/train2/train_batch7818.jpg (deflated 10%)
#   adding: kaggle/working/runs/detect/train2/val_batch1_pred.jpg (deflated 13%)
#   adding: kaggle/working/runs/detect/train2/confusion_matrix_normalized.png (deflated 39%)
#   adding: kaggle/working/runs/detect/train2/labels.jpg (deflated 34%)
#   adding: kaggle/working/runs/detect/train2/F1_curve.png (deflated 17%)
#   adding: kaggle/working/runs/detect/train2/events.out.tfevents.1742652190.29dbe97fb40b.240.0 (deflated 94%)
#   adding: kaggle/working/runs/detect/train2/train_batch7817.jpg (deflated 12%)
#   adding: kaggle/working/runs/detect/train2/confusion_matrix.png (deflated 35%)
#   adding: kaggle/working/runs/detect/train2/val_batch0_labels.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train2/P_curve.png (deflated 19%)
#   adding: kaggle/working/runs/detect/train2/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/detect/train2/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/weights/best.pt (deflated 7%)
#   adding: kaggle/working/runs/detect/train2/weights/last.pt (deflated 7%)
#   adding: kaggle/working/runs/detect/train2/val_batch2_pred.jpg (deflated 23%)
#   adding: kaggle/working/runs/detect/train2/train_batch0.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train2/PR_curve.png (deflated 19%)
#   adding: kaggle/working/runs/detect/train2/train_batch1.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train2/R_curve.png (deflated 18%)
#   adding: kaggle/working/runs/detect/train2/train_batch2.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train2/val_batch1_labels.jpg (deflated 14%)
